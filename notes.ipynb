# %%
# %run -n main.py
# %matplotlib inline

# %%
paths = get_bad_weather_images()

# %%
image = io.imread(paths[30])
roi = get_roi(image)

# %%
imshow(roi)

# %%
split = OrderedDict(split_colors(roi))
split[BACKGROUND] = expand_background(split[BACKGROUND])

# %%
show_split(split)

# %%
unknown = get_unknown(split)
imshow(unknown)

# %%
# %run -n main.py
make_reference_tile(unknown, 'viz/tiles/reference.png')

# %%
guess = guess_unknown(split)

# %%
# %run -n main.py
restored = join_split(guess)
imshow(overlay_mask(restored, unknown, alpha=0.9))

# %%
# %run -n main.py
build_animation(lambda alpha: overlay_mask(restored, unknown, alpha=alpha))
# Out:
# [MoviePy] Building file animation.gif with imageio

# %%
# %run -n main.py
make_tile(
    'images/vnukovo/2015-08-01T11:11:27.532711.png',
    'viz/tiles/2015-08-01T11:11:27.532711.png'
)

# %%
make_titles(get_bad_weather_images())

# %%
dump_tiles_list()
